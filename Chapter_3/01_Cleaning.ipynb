# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../Data/AviationData.txt', sep='|', low_memory=False)

# %%
df.columns
# Out:
# Index(['Event Id ', ' Investigation Type ', ' Accident Number ',
#        ' Event Date ', ' Location ', ' Country ', ' Latitude ', ' Longitude ',
#        ' Airport Code ', ' Airport Name ', ' Injury Severity ',
#        ' Aircraft Damage ', ' Aircraft Category ', ' Registration Number ',
#        ' Make ', ' Model ', ' Amateur Built ', ' Number of Engines ',
#        ' Engine Type ', ' FAR Description ', ' Schedule ',
#        ' Purpose of Flight ', ' Air Carrier ', ' Total Fatal Injuries ',
#        ' Total Serious Injuries ', ' Total Minor Injuries ',
#        ' Total Uninjured ', ' Weather Condition ', ' Broad Phase of Flight ',
#        ' Report Status ', ' Publication Date ', ' '],
#       dtype='object')

# %%
df.head()
# Out:
#          Event Id   Investigation Type   Accident Number    Event Date   \
# 0  20080125X00106             Accident        SEA08CA056    12/31/2007
# 1  20080206X00141             Accident        CHI08WA075    12/31/2007
# 2  20080129X00122             Accident        CHI08CA057    12/30/2007
# 3  20080114X00045             Accident        LAX08FA043    12/30/2007
# 4  20080109X00032             Accident        NYC08FA071    12/30/2007
#
#                     Location           Country     Latitude      Longitude   \
# 0              Santa Ana, CA     United States    33.675556    -117.868056
# 1   Guernsey, United Kingdom    United Kingdom    49.435000      -2.600278
# 2             Alexandria, MN     United States    45.866111     -95.394444
# 3            Paso Robles, CA     United States    35.542222    -120.522778
# 4               Cherokee, AL     United States    34.688611     -87.920000
#
#    Airport Code                  Airport Name   ...  Air Carrier   \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150959 entries, 0 to 150958
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Event Id                  150959 non-null  object
#  1    Investigation Type       150959 non-null  object
#  2    Accident Number          150959 non-null  object
#  3    Event Date               150959 non-null  object
#  4    Location                 150959 non-null  object
#  5    Country                  150959 non-null  object
#  6    Latitude                 150959 non-null  object
#  7    Longitude                150959 non-null  object
#  8    Airport Code             150959 non-null  object
#  9    Airport Name             150959 non-null  object
#  10   Injury Severity          150959 non-null  object
#  11   Aircraft Damage          150959 non-null  object
#  12   Aircraft Category        150959 non-null  object
# ...

# %%
df = df[df[' Country ']==' United States ']

# %%
df[' Country '].value_counts()
# Out:
#  United States     147351
# Name:  Country , dtype: int64

# %%
df.head()
# Out:
#          Event Id   Investigation Type   Accident Number    Event Date   \
# 0  20080125X00106             Accident        SEA08CA056    12/31/2007
# 2  20080129X00122             Accident        CHI08CA057    12/30/2007
# 3  20080114X00045             Accident        LAX08FA043    12/30/2007
# 4  20080109X00032             Accident        NYC08FA071    12/30/2007
# 6  20080103X00010             Accident        DFW08LA052    12/29/2007
#
#            Location          Country     Latitude      Longitude   \
# 0     Santa Ana, CA    United States    33.675556    -117.868056
# 2    Alexandria, MN    United States    45.866111     -95.394444
# 3   Paso Robles, CA    United States    35.542222    -120.522778
# 4      Cherokee, AL    United States    34.688611     -87.920000
# 6       Crowley, TX    United States    32.557222     -97.485555
#
#    Airport Code                  Airport Name   ...  Air Carrier   \
# 0           SNA    John Wayne - Orange County   ...
# ...

# %%
df.isnull().sum()
# Out:
# Event Id                    0
#  Investigation Type         0
#  Accident Number            0
#  Event Date                 0
#  Location                   0
#  Country                    0
#  Latitude                   0
#  Longitude                  0
#  Airport Code               0
#  Airport Name               0
#  Injury Severity            0
#  Aircraft Damage            0
#  Aircraft Category          0
#  Registration Number        0
#  Make                       0
#  Model                      0
#  Amateur Built              0
#  Number of Engines          0
#  Engine Type                0
#  FAR Description            0
#  Schedule                   0
#  Purpose of Flight          0
#  Air Carrier                0
#  Total Fatal Injuries       0
#  Total Serious Injuries     0
#  Total Minor Injuries       0
#  Total Uninjured            0
#  Weather Condition          0
#  Broad Phase of Flight      0
#  Report Status              0
#  Publication Date           0
# ...

# %%
import sys

# %%
sys.getsizeof(df)
# Out:
# 300943573

# %%
df.drop(columns=[' Latitude ', ' Longitude '], inplace=True)

# %%
df.columns
# Out:
# Index(['Event Id ', ' Investigation Type ', ' Accident Number ',
#        ' Event Date ', ' Location ', ' Country ', ' Airport Code ',
#        ' Airport Name ', ' Injury Severity ', ' Aircraft Damage ',
#        ' Aircraft Category ', ' Registration Number ', ' Make ', ' Model ',
#        ' Amateur Built ', ' Number of Engines ', ' Engine Type ',
#        ' FAR Description ', ' Schedule ', ' Purpose of Flight ',
#        ' Air Carrier ', ' Total Fatal Injuries ', ' Total Serious Injuries ',
#        ' Total Minor Injuries ', ' Total Uninjured ', ' Weather Condition ',
#        ' Broad Phase of Flight ', ' Report Status ', ' Publication Date ',
#        ' '],
#       dtype='object')

# %%
df.head()
# Out:
#          Event Id   Investigation Type   Accident Number    Event Date   \
# 0  20080125X00106             Accident        SEA08CA056    12/31/2007
# 2  20080129X00122             Accident        CHI08CA057    12/30/2007
# 3  20080114X00045             Accident        LAX08FA043    12/30/2007
# 4  20080109X00032             Accident        NYC08FA071    12/30/2007
# 6  20080103X00010             Accident        DFW08LA052    12/29/2007
#
#            Location          Country   Airport Code   \
# 0     Santa Ana, CA    United States            SNA
# 2    Alexandria, MN    United States            AXN
# 3   Paso Robles, CA    United States            PRB
# 4      Cherokee, AL    United States
# 6       Crowley, TX    United States
#
#                   Airport Name   Injury Severity   Aircraft Damage   ...  \
# 0   John Wayne - Orange County         Non-Fatal       Substantial   ...
# 2       Chandler Field Airport         Non-Fatal       Substantial   ...
# ...

# %%
df.columns = [col.lower().replace(' ', '_') for col in df.columns]

# %%
df.head()
# Out:
#          event_id_ _investigation_type_ _accident_number_  _event_date_  \
# 0  20080125X00106             Accident        SEA08CA056    12/31/2007
# 2  20080129X00122             Accident        CHI08CA057    12/30/2007
# 3  20080114X00045             Accident        LAX08FA043    12/30/2007
# 4  20080109X00032             Accident        NYC08FA071    12/30/2007
# 6  20080103X00010             Accident        DFW08LA052    12/29/2007
#
#           _location_        _country_ _airport_code_  \
# 0     Santa Ana, CA    United States            SNA
# 2    Alexandria, MN    United States            AXN
# 3   Paso Robles, CA    United States            PRB
# 4      Cherokee, AL    United States
# 6       Crowley, TX    United States
#
#                  _airport_name_ _injury_severity_ _aircraft_damage_  ...  \
# 0   John Wayne - Orange County         Non-Fatal       Substantial   ...
# 2       Chandler Field Airport         Non-Fatal       Substantial   ...
# ...

# %%
cols = list(df.columns)

# %%
cols
# Out:
# ['event_id_',
#  '_investigation_type_',
#  '_accident_number_',
#  '_event_date_',
#  '_location_',
#  '_country_',
#  '_airport_code_',
#  '_airport_name_',
#  '_injury_severity_',
#  '_aircraft_damage_',
#  '_aircraft_category_',
#  '_registration_number_',
#  '_make_',
#  '_model_',
#  '_amateur_built_',
#  '_number_of_engines_',
#  '_engine_type_',
#  '_far_description_',
#  '_schedule_',
#  '_purpose_of_flight_',
#  '_air_carrier_',
#  '_total_fatal_injuries_',
#  '_total_serious_injuries_',
#  '_total_minor_injuries_',
#  '_total_uninjured_',
#  '_weather_condition_',
#  '_broad_phase_of_flight_',
#  '_report_status_',
#  '_publication_date_',
#  '_']

# %%
df['_engine_type_'].value_counts()
# Out:
#                    86403
#  Reciprocating     52854
#  Turbo Shaft        2440
#  Turbo Prop         2205
#  Turbo Fan          1525
#  Unknown            1365
#  Turbo Jet           558
#  REC, TJ, TJ           1
# Name: _engine_type_, dtype: int64

# %%
df['_far_description_'].value_counts()
# Out:
#  Part 91 General Aviation           80254
#                                     54007
#  Part 91: General Aviation           6434
#  Part 135 Nonscheduled               3008
#  Part 121 Scheduled                  1367
#  Part 135 Scheduled                   781
#  Part 137: Agricultural               436
#  General Aviation Forn                348
#  Part 135: Air Taxi & Commuter        288
#  Part 121 Nonscheduled                157
#  Part 121: Air Carrier                110
#  Part 129 Scheduled                    58
#  Part 133: Rotorcraft Ext. Load        32
#  Part 129 Nonscheduled                 23
#  Public Use                            16
#  Part 129: Foreign                     14
#  Unknown                               10
#  Part 125: 20+ Pax,6000+ lbs            4
#  Public Aircraft                        2
#  Part 91 Subpart K: Fractional          1
#  Part 91F: Special Flt Ops.             1
# Name: _far_description_, dtype: int64

# %%
df.drop(columns='_', inplace=True)

# %%
df.head()
# Out:
#          event_id_ _investigation_type_ _accident_number_  _event_date_  \
# 0  20080125X00106             Accident        SEA08CA056    12/31/2007
# 2  20080129X00122             Accident        CHI08CA057    12/30/2007
# 3  20080114X00045             Accident        LAX08FA043    12/30/2007
# 4  20080109X00032             Accident        NYC08FA071    12/30/2007
# 6  20080103X00010             Accident        DFW08LA052    12/29/2007
#
#           _location_        _country_ _airport_code_  \
# 0     Santa Ana, CA    United States            SNA
# 2    Alexandria, MN    United States            AXN
# 3   Paso Robles, CA    United States            PRB
# 4      Cherokee, AL    United States
# 6       Crowley, TX    United States
#
#                  _airport_name_ _injury_severity_ _aircraft_damage_  ...  \
# 0   John Wayne - Orange County         Non-Fatal       Substantial   ...
# 2       Chandler Field Airport         Non-Fatal       Substantial   ...
# ...

# %%
cols
# Out:
# ['event_id_',
#  '_investigation_type_',
#  '_accident_number_',
#  '_event_date_',
#  '_location_',
#  '_country_',
#  '_airport_code_',
#  '_airport_name_',
#  '_injury_severity_',
#  '_aircraft_damage_',
#  '_aircraft_category_',
#  '_registration_number_',
#  '_make_',
#  '_model_',
#  '_amateur_built_',
#  '_number_of_engines_',
#  '_engine_type_',
#  '_far_description_',
#  '_schedule_',
#  '_purpose_of_flight_',
#  '_air_carrier_',
#  '_total_fatal_injuries_',
#  '_total_serious_injuries_',
#  '_total_minor_injuries_',
#  '_total_uninjured_',
#  '_weather_condition_',
#  '_broad_phase_of_flight_',
#  '_report_status_',
#  '_publication_date_',
#  '_']

# %%
list(cols[0])
# Out:
# ['e', 'v', 'e', 'n', 't', '_', 'i', 'd', '_']

# %%
cols2= []
for n in range(len(cols)):
    wordlist=[]
    wordlist=list(cols[n])
    wordlist=wordlist[1:-1]
    cols2.append(''.join(wordlist))
cols2
# Out:
# ['vent_id',
#  'investigation_type',
#  'accident_number',
#  'event_date',
#  'location',
#  'country',
#  'airport_code',
#  'airport_name',
#  'injury_severity',
#  'aircraft_damage',
#  'aircraft_category',
#  'registration_number',
#  'make',
#  'model',
#  'amateur_built',
#  'number_of_engines',
#  'engine_type',
#  'far_description',
#  'schedule',
#  'purpose_of_flight',
#  'air_carrier',
#  'total_fatal_injuries',
#  'total_serious_injuries',
#  'total_minor_injuries',
#  'total_uninjured',
#  'weather_condition',
#  'broad_phase_of_flight',
#  'report_status',
#  'publication_date',
#  '']

# %%
cols2 = cols2[:-1]

# %%
cols2
# Out:
# ['vent_id',
#  'investigation_type',
#  'accident_number',
#  'event_date',
#  'location',
#  'country',
#  'airport_code',
#  'airport_name',
#  'injury_severity',
#  'aircraft_damage',
#  'aircraft_category',
#  'registration_number',
#  'make',
#  'model',
#  'amateur_built',
#  'number_of_engines',
#  'engine_type',
#  'far_description',
#  'schedule',
#  'purpose_of_flight',
#  'air_carrier',
#  'total_fatal_injuries',
#  'total_serious_injuries',
#  'total_minor_injuries',
#  'total_uninjured',
#  'weather_condition',
#  'broad_phase_of_flight',
#  'report_status',
#  'publication_date']

# %%
cols2[0] = 'event_id'

# %%
cols2
# Out:
# ['event_id',
#  'investigation_type',
#  'accident_number',
#  'event_date',
#  'location',
#  'country',
#  'airport_code',
#  'airport_name',
#  'injury_severity',
#  'aircraft_damage',
#  'aircraft_category',
#  'registration_number',
#  'make',
#  'model',
#  'amateur_built',
#  'number_of_engines',
#  'engine_type',
#  'far_description',
#  'schedule',
#  'purpose_of_flight',
#  'air_carrier',
#  'total_fatal_injuries',
#  'total_serious_injuries',
#  'total_minor_injuries',
#  'total_uninjured',
#  'weather_condition',
#  'broad_phase_of_flight',
#  'report_status',
#  'publication_date']

# %%
cols = cols[:-1]

# %%
cols
# Out:
# ['event_id_',
#  '_investigation_type_',
#  '_accident_number_',
#  '_event_date_',
#  '_location_',
#  '_country_',
#  '_airport_code_',
#  '_airport_name_',
#  '_injury_severity_',
#  '_aircraft_damage_',
#  '_aircraft_category_',
#  '_registration_number_',
#  '_make_',
#  '_model_',
#  '_amateur_built_',
#  '_number_of_engines_',
#  '_engine_type_',
#  '_far_description_',
#  '_schedule_',
#  '_purpose_of_flight_',
#  '_air_carrier_',
#  '_total_fatal_injuries_',
#  '_total_serious_injuries_',
#  '_total_minor_injuries_',
#  '_total_uninjured_',
#  '_weather_condition_',
#  '_broad_phase_of_flight_',
#  '_report_status_',
#  '_publication_date_']

# %%
len(cols)
# Out:
# 29

# %%
len(cols2)
# Out:
# 29

# %%
len(df)
# Out:
# 147351

# %%
df.shape
# Out:
# (147351, 29)

# %%
col_dict = dict(zip(cols,cols2))

# %%
col_dict
# Out:
# {'event_id_': 'event_id',
#  '_investigation_type_': 'investigation_type',
#  '_accident_number_': 'accident_number',
#  '_event_date_': 'event_date',
#  '_location_': 'location',
#  '_country_': 'country',
#  '_airport_code_': 'airport_code',
#  '_airport_name_': 'airport_name',
#  '_injury_severity_': 'injury_severity',
#  '_aircraft_damage_': 'aircraft_damage',
#  '_aircraft_category_': 'aircraft_category',
#  '_registration_number_': 'registration_number',
#  '_make_': 'make',
#  '_model_': 'model',
#  '_amateur_built_': 'amateur_built',
#  '_number_of_engines_': 'number_of_engines',
#  '_engine_type_': 'engine_type',
#  '_far_description_': 'far_description',
#  '_schedule_': 'schedule',
#  '_purpose_of_flight_': 'purpose_of_flight',
#  '_air_carrier_': 'air_carrier',
#  '_total_fatal_injuries_': 'total_fatal_injuries',
#  '_total_serious_injuries_': 'total_serious_injuries',
#  '_total_minor_injuries_': 'total_minor_injuries',
#  '_total_uninjured_': 'total_uninjured',
# ...

# %%
df = df.rename(columns=col_dict)

# %%
df['air_carrier'].value_counts()
# Out:
#                                     144369
#  UNITED AIRLINES                        46
#  AMERICAN AIRLINES                      33
#  CONTINENTAL AIRLINES                   25
#  USAIR                                  24
#                                      ...
#  Name                                    1
#  MOUNTAIN AIR CARGO INC.                 1
#  AIR NEVADA AIRLINES, INC.               1
#  HAWKINS AIR (DBA: hawkins air)          1
#  NORTHERN AIR                            1
# Name: air_carrier, Length: 2245, dtype: int64

# %%
df.drop(columns='air_carrier', inplace=True)

# %%
df.columns
# Out:
# Index(['event_id', 'investigation_type', 'accident_number', 'event_date',
#        'location', 'country', 'airport_code', 'airport_name',
#        'injury_severity', 'aircraft_damage', 'aircraft_category',
#        'registration_number', 'make', 'model', 'amateur_built',
#        'number_of_engines', 'engine_type', 'far_description', 'schedule',
#        'purpose_of_flight', 'total_fatal_injuries', 'total_serious_injuries',
#        'total_minor_injuries', 'total_uninjured', 'weather_condition',
#        'broad_phase_of_flight', 'report_status', 'publication_date'],
#       dtype='object')

# %%
df.drop(columns='report_status', inplace=True)

# %%
df.columns
# Out:
# Index(['event_id', 'investigation_type', 'accident_number', 'event_date',
#        'location', 'country', 'airport_code', 'airport_name',
#        'injury_severity', 'aircraft_damage', 'aircraft_category',
#        'registration_number', 'make', 'model', 'amateur_built',
#        'number_of_engines', 'engine_type', 'far_description', 'schedule',
#        'purpose_of_flight', 'total_fatal_injuries', 'total_serious_injuries',
#        'total_minor_injuries', 'total_uninjured', 'weather_condition',
#        'broad_phase_of_flight', 'publication_date'],
#       dtype='object')

# %%
df['investigation_type'].value_counts()
# Out:
#               85996
#  Accident     59482
#  Incident      1873
# Name: investigation_type, dtype: int64

# %%
df['amateur_built'].value_counts()
# Out:
#  No      139987
#  Yes       7343
#              21
# Name: amateur_built, dtype: int64

# %%
df['amateur_built'] = df['amateur_built'].str.replace(' ', '')

# %%
df['amateur_built'] = df['amateur_built'].map({'Yes':1, 'No':0})

# %%
df['amateur_built'].value_counts()
# Out:
# 0.0    139987
# 1.0      7343
# Name: amateur_built, dtype: int64

# %%
df['amateur_built'].isnull().sum()
# Out:
# 21

# %%
df[df['amateur_built'].isnull()]
# Out:
#               event_id investigation_type accident_number    event_date  \
# 618    20070927X01454           Accident     NYC07LA208B    09/02/2007
# 822    20071129X01869           Accident      NYC07LA248    08/03/2007
# 1721   20070610X00702           Incident     OPS07IA003A    03/16/2007
# 2251   20061108X01625           Incident     DEN07IA021B    11/06/2006
# 2604   20061012X01503           Accident      CHI06FA275    08/24/2006
# 3061   20060712X00929           Incident      ENG06IA020    06/14/2006
# 3722   20060215X00204           Accident     LAX06FA106B    02/08/2006
# 4233   20071221X01980           Incident      ENG06IA001    10/09/2005
# 4474   20050915X01471           Accident      CHI05TA251    08/31/2005
# 4504   20050917X01488           Accident      IAD05FA146    08/26/2005
# 4708   20050811X01222           Accident      SEA05CA156    07/30/2005
# 4710   20050921X01504           Accident      LAX05LA251    07/30/2005
# ...

# %%
df
# Out:
#                event_id investigation_type accident_number    event_date  \
# 0       20080125X00106           Accident      SEA08CA056    12/31/2007
# 2       20080129X00122           Accident      CHI08CA057    12/30/2007
# 3       20080114X00045           Accident      LAX08FA043    12/30/2007
# 4       20080109X00032           Accident      NYC08FA071    12/30/2007
# 6       20080103X00010           Accident      DFW08LA052    12/29/2007
# ...                 ...                ...             ...           ...
# 150953           24239                         LAX68F0032
# 150954           24240                         OAK69A0051
# 150956           24241                         NYC73DKM11
# 150957           24237                         NYC65I0127
# 150958           24243                         LAX78DUJ68
#
#                     location          country airport_code  \
# 0             Santa Ana, CA    United States          SNA
# ...

# %%
#df.to_csv('airplanes.csv', index=False)
